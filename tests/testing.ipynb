# %%
from AutoDataPreprocess import AutoDataPreprocess , load
x = load('default of credit card clients.xlsx')

# %%
x.basic_analysis()
# Out:
# Memory Usage Analysis:
# Index             128
# Unnamed: 0    1080059
# X1            1080066
# X2            1080060
# X3            1080010
# X4            1079849
# X5            1080060
# X6            1021114
# X7            1017142
# X8            1017006
# X9            1014242
# X10           1012274
# X11           1014918
# X12           1072034
# X13           1070042
# X14           1068586
# X15           1067286
# X16           1066042
# X17           1063986
# X18           1059069
# X19           1058481
# X20           1056193
# X21           1054433
# X22           1053253
# X23           1051373
# Y              986627
# dtype: int64
#
# Total Memory Usage: 25.09 MB
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30001 non-null  object
# ...

# %%
x.clean(missing='knn', outliers='iqr', drop_threshold=0.8, date_format='%Y-%m-%d', remove_duplicates=True)
